# %% [markdown]
# **Convert categorical to numerical column**
#
# - Before we develop ML algorithm, It is very important to do
# - ML algorithms developed maths

# %% [markdown]
# - Map
#
# - np.where
#
# - pd.getDummies
#
# - LabelEncoder

# %% [markdown]
# **Import the packages**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Read the data**

# %%
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Separate Numerical and Categorical Columns**

# %%
cat,num=[],[]
for key,values in dict(visa_dataset.dtypes).items():
    if values=='O':
        cat.append(key)
    else:
        num.append(key)

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
categorical=[key for key,values in visa_dataset.dtypes.items() if values=="object"]
numeric=[key for key,values in visa_dataset.dtypes.items() if values!="object"]
print(categorical,numeric)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status'] ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
categorical=[key for key,values in dict(visa_dataset.dtypes).items() if values=="object"]
numeric=[key for key,values in dict(visa_dataset.dtypes).items() if values!="object"]
print(categorical,numeric)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status'] ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# $Method-1:$

# %% [markdown]
# **Map**

# %%
# case_status is a categorical column
visa_dataset['case_status'].unique()

# How many labels are there
# In case_status two label are there
# Denied=0
# Certified=1
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# Create a dictionary with
# Denied = 0
# Certified = 1

dict1={'Denied':0,'Certified':1}

# %%
dict1
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
# which column labels you want to map with dictionary

visa_dataset['case_status'].map(dict1)
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: case_status, Length: 25480, dtype: int64

# %%
# How to create a new column
visa_dataset.columns

# I want to create new column with number
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# Vheck shape of original dataset
visa_dataset.shape
# Out:
# (25480, 12)

# %%
list1=[i for i in range(25480)]
len(list1)
# Out:
# 25480

# %%
visa_dataset['Number']=list1

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Number 2
visa_dataset['Number2']=2

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# you want to create a new columns
# i want to drop columns

# %%
# number column is created i want to drop that
# column means axis=1
visa_dataset.drop('Number',axis=1,inplace=True)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset.drop('Number2',axis=1,inplace=True)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# All together creating columns

list1=[i for i in range(25480)]
visa_dataset['Number1']=list1
visa_dataset['Number2']=2

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# All together to drop columns

visa_dataset.drop('Number1',axis=1,inplace=True)
visa_dataset.drop('Number2',axis=1,inplace=True)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Step-1 : Check how many labels are there
visa_dataset['case_status'].unique()
# Step-2 : Create a dictionary
dict1={'Denied':0,'Certified':1}
# Step-3 : Map to the function
visa_dataset['case_status']=visa_dataset['case_status'].map(dict1)

# %%
# visa_dataset.drop('case_status',axis=1,inplace=True)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# What is the drawback in map method
# Creating a dictionary
# 20 labels

# %%
# Two lists  ======  dictionary
list1=['Ram','Sita','Laxman']
list2=[25,22,20]

dict1={'Ram':25,'Sita':22,'Laxman':20}

# %%
# Read the data again
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
keys=visa_dataset['case_status'].unique()
values=[i for i in range(len(keys))]
values

# Create dictionary comprehension
# If i give two lists how to make a dictionary
# Out:
# [0, 1]

# %%
print(keys)
# Out:
# ['Denied' 'Certified']

# %%
visa_dataset['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %%
visa_dataset['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
type(visa_dataset['case_status'].unique())
# Out:
# numpy.ndarray

# %%
dict1={'Denied':0,'Certified':1}

# %% [markdown]
# $Method-2:$

# %%
# Read the data : 
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
case_status == denied then replace denied with 0
otherwise all values are 1

# %%
cond=visa_dataset['case_status']=='Denied'
visa_dataset['case_status']=np.where(cond,0,1)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Drawback only appicable to binary

# %% [markdown]
# $Method-3:$

# %% [markdown]
# **pd.get_dummies**

# %%
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
pd.get_dummies(visa_dataset['education_of_employee'])

# there are 4 labels are there
# pd.get_dummies will create extra 4 columns
# B  D  H  M
# 0  0  1  0
# 0  0  0  1

# ON-OFF : SET-RESET
# ON-OFF ======>> Cos function
# COS0=1   COS90=0
#  0        90
# both are perpendicular each other
# orthogonal each other
# 90 degrees phase shift
# there is no relation, independent each other
# Out:
#        Bachelor's  Doctorate  High School  Master's
# 0               0          0            1         0
# 1               0          0            0         1
# 2               1          0            0         0
# 3               1          0            0         0
# 4               0          0            0         1
# ...           ...        ...          ...       ...
# 25475           1          0            0         0
# 25476           0          0            1         0
# 25477           0          0            0         1
# 25478           0          0            0         1
# 25479           1          0            0         0
#
# [25480 rows x 4 columns]

# %%
# EDA

# 1) Read the data and perform the quick checks, apply the data retreival process
# - If any missing value is there fill here only
# - Loan prediction data : 
# Clean Up Process
# - 1
# - 2
# - 3+

# 2) Categorical Analysis : all categorical columns
# - Drawing the plots
# - Subplots

=============================================================

                          Insights

=============================================================

# 3) Numerical column analysis
# - Histogram
# - Box-Plot
# - Outlier Analysis

# 4) Bivariate Analysis
# - Analyse some columns together
# - Input COlums loan status
# - pd.crosstab
# - plots

# 5) Categorical to Numerical
# - map
# - np.where
# - pd.get_dummies
# - label encoder

# 6) Normalisation and standardisation
# -

# %%
# read the data again

# %%
import numpy as np
import pandas as pd

# %%
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# my visa dataset will create extra 2 new columns
# Denied and Certified
pd.get_dummies(visa_dataset['case_status'])
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
df1=pd.get_dummies(visa_dataset,
               columns=['case_status'])

# two new 

# case_sttaus_Certfied
# case_status_Denied

# %%
df1.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status_Certified', 'case_status_Denied'],
#       dtype='object')

# %%
visa_dataset.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
pd.get_dummies(visa_dataset,prefix='Naresh_IT',columns=['case_status'])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(cat)
# Out:
# 9

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cat[1:]
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
s=0
for i in cat[1:]:
    a=visa_dataset[i].nunique()
    
    s+=a
    
print(s)

# 27 extra columns created
# Out:
# 27

# %%
visa_dataset.shape
# Out:
# (25480, 12)

# %% [markdown]
# - we are increasing dimensions
# - data will be sparse
#
# **curse of dimensionality**
# - Memory issue
# - time complexity
# - learning process will be slow

# %% [markdown]
# ### Less data go with pd.get_dummies
#
# **Advantages:**
# - No relation
# - Perpendicular
# - 90 degree phase shift
# - Orthogonality
# - Columns are independent each other
#
# **Disadvantages:**
# ###### Curse of dimensionality:-
# - memory issue
# - time complexity
# - learning process will be slow

# %% [markdown]
# $Method-4:$

# %% [markdown]
# **Label Encoder**

# %%
# Automation of map method

# %%
keys=visa_dataset['continent'].unique()
keys
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_dataset['continent'].nunique()
# Out:
# 6

# %%
visa_dataset['continent'].value_counts()
# Out:
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: continent, dtype: int64

# %%
type(visa_dataset['continent'].value_counts())
# Out:
# pandas.core.series.Series

# %%
visa_dataset['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object')

# %%
visa_dataset['continent'].value_counts().to_list()
# Out:
# [16861, 3732, 3292, 852, 551, 192]

# %%
values=[i for i in range(len(keys))]
values
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
d1={keys[i]:values[i] for i in range(len(keys))}
d1
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
visa_dataset['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
keys=visa_dataset['continent'].unique()
values=[i for i in range(len(keys))]
d1={keys[i]:values[i] for i in range(len(keys))}
visa_dataset['continent'].map(d1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: continent, Length: 25480, dtype: int64

# %%
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_dataset['continent_new']=le.fit_transform(visa_dataset['continent'])

# %%
visa_dataset['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_dataset['continent_new']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: continent_new, Length: 25480, dtype: int32

# %%
visa_dataset[['continent','continent_new']]
# Out:
#       continent  continent_new
# 0          Asia              1
# 1          Asia              1
# 2          Asia              1
# 3          Asia              1
# 4        Africa              0
# ...         ...            ...
# 25475      Asia              1
# 25476      Asia              1
# 25477      Asia              1
# 25478      Asia              1
# 25479      Asia              1
#
# [25480 rows x 2 columns]

# %%
keys=visa_dataset['continent'].unique()

# %%
keys
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
len(keys)
# Out:
# 6

# %%
visa_dataset['continent_new'].unique()
# Out:
# array([1, 0, 3, 2, 5, 4])

# %%
# All together
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset

from sklearn.preprocessing import LabelEncoder  # Import the package
le=LabelEncoder()  # save the package
visa_dataset['continent']=le.fit_transform(visa_dataset['continent']) # Apply fit transform

# %%
visa_dataset['continent']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: continent, Length: 25480, dtype: int32

# %%
converted=visa_dataset['continent'].values
converted
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
original=le.inverse_transform(visa_dataset['continent'])
original
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %%
print(converted[:10])
print(original[:10])
# Out:
# [1 1 1 1 0 1 1 3 1 2]
# ['Asia' 'Asia' 'Asia' 'Asia' 'Africa' 'Asia' 'Asia' 'North America' 'Asia'
#  'Europe']

# %%
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# All together
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Sessions\\Session_3_Numerical_Analysis\\Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset

from sklearn.preprocessing import LabelEncoder  # Import the package
le=LabelEncoder()  # save the package

for i in cat[1:]:
    visa_dataset[i]=le.fit_transform(visa_dataset[i]) # Apply fit transform

visa_dataset
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# $fit$-$transform$

# %%
# Fit means
# you are setting up to create an output
# Case_status
# certified  denied
#  0          1
# d={'c':0,'d':1}============================= fit
keys=visa_dataset['continent'].unique()
values=[i for i in range(len(keys))]
d={keys[i]:values[i] for i in range(len(keys))}

# transform that output on original data
visa_dataset['continent'].map(d)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: continent, Length: 25480, dtype: int64
