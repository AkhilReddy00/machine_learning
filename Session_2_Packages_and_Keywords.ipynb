# %%
# EDA
# packages required are

# Pandas ==== dataframe analysis
# numpy ==== numerical python ==== number analysis
# matplotlib ( mat - plot - library ) ==== to plot any diagrams
# seaborn ==== to plot diagrams
# bokhe ==== plot diagrams

# plot the diagrams ==== data visualisation (power bi/tableau)

# %%
# ML

# sikitlearn ====>> sklearn

# image analytics
# tensorflow(Deep Learning) ====>> google
# opencv (we need to install)
# keras

# text analytics (NLP)
# NLTK (natural language tool kit)
#scipy

# BERT Transformers (ML+DL+NLP) Hugging Face
# transformers

# chatGPT model (Ml+DL+NLP)
# LLM

# %% [markdown]
# $Step - 1$
#
# **Import the packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $Step - 2$
#
# **Read the data**

# %%
# file location
# file name
# extension

# <file_location>//<file_name>.<extension>

# visa datasets
# .csv(comma separated value), .txt, .xlsx(excel)

C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1

visaset

.csv

"C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Visadataset.csv"

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1'

# %%
file_name="C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\Visadataset.csv"
pd.read_csv(file_name)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
file_name='C:\\Users\\hp\\Data Science and AI\\Naresh IT\\Statistics_PART_1\\bank.csv'
pd.read_csv(file_name,sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# while reading the file
# take care of many thingss
# file path, headers, sep

# %%
visa_dataset=pd.read_csv(file_name,sep=';')

# %%
type(visa_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
visa_dataset.shape
# Out:
# (4521, 1)

# %%
type(visa_dataset.shape)
# Out:
# tuple

# %%
visa_dataset.size # total number of observations
# Out:
# 4521

# %%
type(visa_dataset.size)
# Out:
# numpy.int32

# %%
dir(visa_dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
visa_dataset.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
visa_dataset.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
visa_dataset.take([0,1,2])
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %%
visa_dataset.take([0,1,2],axis=1)
# Out:
#       age            job  marital
# 0      30     unemployed  married
# 1      33       services  married
# 2      35     management   single
# 3      30     management  married
# 4      59    blue-collar  married
# ...   ...            ...      ...
# 4516   33       services  married
# 4517   57  self-employed  married
# 4518   57     technician  married
# 4519   28    blue-collar  married
# 4520   44   entrepreneur   single
#
# [4521 rows x 3 columns]

# %%
visa_dataset.take([0,1,2],axis=0)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %%
# I want 150 250 350 rows from 5 8 12 colums

# %%
visa_dataset.take([5,8,12],axis=1)
# Out:
#       balance   contact  campaign
# 0        1787  cellular         1
# 1        4789  cellular         1
# 2        1350  cellular         1
# 3        1476   unknown         4
# 4           0   unknown         1
# ...       ...       ...       ...
# 4516     -333  cellular         5
# 4517    -3313   unknown         1
# 4518      295  cellular        11
# 4519     1137  cellular         4
# 4520     1136  cellular         2
#
# [4521 rows x 3 columns]

# %%
visa_dataset.take([150,250,350],axis=0)
# Out:
#      age           job  marital  education default  balance housing loan  \
# 150   41  entrepreneur  married    unknown      no       89     yes   no
# 250   31    management  married   tertiary      no      395     yes   no
# 350   31   blue-collar  married  secondary      no     1660     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 150   unknown    6   may       333         2     -1         0  unknown  no
# 250  cellular    9   feb       155         3     -1         0  unknown  no
# 350  cellular   20   apr       342         1     -1         0  unknown  no

# %%
visa_dataset.take([5,8,12],axis=1).take([150,250,350])
# Out:
#      balance   contact  campaign
# 150       89   unknown         2
# 250      395  cellular         3
# 350     1660  cellular         1

# %% [markdown]
# $loc - iloc$

# %%
<datframe>.iloc[rows,columns]
<dataframe>.iloc[start:end,start:end]

# %%
visa_dataset=pd.read_csv(file_name)

# %%
visa_dataset.iloc[1:6,0:3]
# Out:
#   case_id continent education_of_employee
# 1  EZYV02      Asia              Master's
# 2  EZYV03      Asia            Bachelor's
# 3  EZYV04      Asia            Bachelor's
# 4  EZYV05    Africa              Master's
# 5  EZYV06      Asia              Master's

# %%
visa_dataset.take([0,1,2],axis=1).take([1,2,3,4,5])
# Out:
#   case_id continent education_of_employee
# 1  EZYV02      Asia              Master's
# 2  EZYV03      Asia            Bachelor's
# 3  EZYV04      Asia            Bachelor's
# 4  EZYV05    Africa              Master's
# 5  EZYV06      Asia              Master's

# %%
# get rows from 100 to 105 and 7 to 11 columns

# %%
visa_dataset.iloc[100:106,7:12]
# Out:
#     region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 100            Northeast         28243.79         Year                  Y
# 101              Midwest         43421.88         Year                  Y
# 102              Midwest         80253.78         Year                  Y
# 103                 West        115235.95         Year                  Y
# 104            Northeast         95200.86         Year                  N
# 105               Island         41613.52         Year                  Y
#
#     case_status
# 100   Certified
# 101   Certified
# 102   Certified
# 103   Certified
# 104   Certified
# 105   Certified

# %%
visa_dataset.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_dataset.iloc[[100,200,300],[7,11]]
# Out:
#     region_of_employment case_status
# 100            Northeast   Certified
# 200                 West   Certified
# 300              Midwest   Certified

# %%
# 2200 and 1700 row from prevailing wage column

# %%
visa_dataset.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_dataset.columns[8]
# Out:
# 'prevailing_wage'

# %%
visa_dataset.iloc[[2200,1700],[8]]
# Out:
#       prevailing_wage
# 2200         22856.14
# 1700        177310.49

# %%
# drawback : columns are manually counted
# it is not possible to manually count if there are 100 rows

# %%
# to avoid drawback count the index of columns we use loc

# %%
visa_dataset.loc[[2200,1700],['prevailing_wage']]
# Out:
#       prevailing_wage
# 2200         22856.14
# 1700        177310.49

# %%
# education of employee, no. of employess, case status

# %%
visa_dataset.loc[[100,200,300],['education_of_employee','no_of_employees','case_status']]
# Out:
#     education_of_employee  no_of_employees case_status
# 100              Master's             2227   Certified
# 200             Doctorate             3282   Certified
# 300              Master's             3268   Certified

# %%
visa_dataset.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_dataset.columns) 

# it is not a list
# it can be typecast into list
# Out:
# pandas.core.indexes.base.Index

# %%
list(visa_dataset)
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
col_list=list(visa_dataset)
col_list.index('prevailing_wage')
# Out:
# 8

# %%
wage_index=col_list.index('prevailing_wage')
wage_index
# Out:
# 8

# %%
visa_dataset.iloc[[2200,1700],[wage_index]]
# Out:
#       prevailing_wage
# 2200         22856.14
# 1700        177310.49

# %% [markdown]
# $dtypes:$

# %%
visa_dataset.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_dataset.dtypes)
# Out:
# pandas.core.series.Series

# %%
visa_dataset.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %%
# convert series data to dict or list

# %%
dict(visa_dataset.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %% [markdown]
# **Series type can be typecasted into dictionary using dictionary type casting**
#
# **Anything can be converted into list or dict**
#
# **If you give list or dictionary you can convert it to dataframe**

# %%
cols_dict=dict(visa_dataset.dtypes)
for key,value in cols_dict.items():
    print(key,'====',value)
# Out:
# case_id ==== object
# continent ==== object
# education_of_employee ==== object
# has_job_experience ==== object
# requires_job_training ==== object
# no_of_employees ==== int64
# yr_of_estab ==== int64
# region_of_employment ==== object
# prevailing_wage ==== float64
# unit_of_wage ==== object
# full_time_position ==== object
# case_status ==== object

# %%
cols_dict=dict(visa_dataset.dtypes)
cat_list=[]
num_list=[]
for key,value in cols_dict.items():
    if value=='O':
        cat_list.append(key)
    else:
        num_list.append(key)
cat_list,num_list
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
cat_list=[key for key,value in cols_dict.items() if value=='O']
num_list=[key for key,value in cols_dict.items() if value!='O']

# %%
cat_list,num_list
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %% [markdown]
# $info$

# %%
visa_dataset.info()

# How many entries are there: 25480
# start and end index: 0 and 25479
# what is the type of visa_dataset: dataframe
# number of columns: 12
# column name
# Any missing values are there: Non-Null count
# Age: 30 rows === > 10 missing values are there:  Non-Null count: 20
# There is No missing values
# Data type
# Count of different data types
# Memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $isnull$

# %%
visa_dataset.isnull()

# isnull it is a qn ===== computer
# what is the computer response

# wherever True that means null value is there
# null value: there is no value 
# value is Missed
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_dataset.isnull().sum()

# case_id   1   ======> there is one missing value is there under case id column
# case_id column first
# then you can get that row

# Missing values analysis sepearte session is there
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# - read the data
#
# - shape
#
# - columns
#
# - size
#
# - type
#
# - len
#
# - head
#
# - tail
#
# - take
#
# - iloc
#
# - loc
#
# - type casting
#
# - columns
#
# - dtypes
#
# - cat and numerical
#
# - info
#
# - isnull
